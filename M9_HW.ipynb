# %% [markdown]
# <a href="https://colab.research.google.com/github/Sohail3430/sohail2/blob/main/M9_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
import numpy as np
import math as m

def theMax(numbers):
  my_max = numbers[0]
  for i in numbers:
    if my_max < i:
      my_max = i
  return my_max

def themin(numbers):
  my_min = numbers[0]
  for i in numbers:
    if my_min < i:
      my_min = i
  return my_min

def theAverage(numbers):
  total = 0
  for i in numbers:
    total += i
  return total/len(numbers)

def theGeoMean(numbers):
  total = 0
  for i in numbers:
    total += i
  return total**(1/len(numbers)
  
def theStadardDev(numbers):
  theAvg = theAverage(numbers)
  total = 0
  for i in numbers:
    total = total + ((i-theAvg)**2
  return m.sqrt(total/(len(numbers)-1))

a = [8,6,2,9,13,3]
print(theMax(a))
print(theGeoMean(a))
print(theStandardDev(a))
# Out:
#   File "<ipython-input-11-16905b38582e>", line 31
#     def theStadardDev(numbers):
#       ^
# SyntaxError: invalid syntax

# %%
from typing import Sized
def cicleArea(radius):
  return m.piradius**2

def rectangleArea(length, width):
  return lenght*width

def sqareArea(side):
  return side*sized

def traiangleArea(base, height):
  return base*height/2

def genralArea():
  Value

#not done

generalArea()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-584ad8dd5a65> in <module>()
#      17
#      18
# ---> 19 generalArea()
#
# NameError: name 'generalArea' is not defined

# %%
import numpy as np
def listDoubleling():
  x = [1,2,3]
  y = [1,2,3]
  choice = int(input("would you like it double by the way (1) or way two (2)?"))
  if choice == 1:
    print(x+y)
  else:
    print(np.array(x)+ np.array(y))

listDoubleling()
# Out:
# would you like it double by the way (1) or way two (2)?2
# [2 4 6]

# %%
def concatenatepositions(list1, list2):
  myBigList = []
  for i in range(len(liost1)):
    myBiglist.append(float(str(list1[i])+str(list2[i])))
  return myBigList

  list1 = [1,2,3]
  list2 = [7,8,9]
  biglist = np.concatenatepositions(list1,list2)
  print(biglist)

# %%
def is Prime(num):
  for i in range(2,num):
    if (num%i == 0):
      return False
  return True

def listPrimes(amount):
  # an empty list
  my list = []
  count = 0
  checkVal = 2
  while (count < amount):
    if(isPrime(checkVal:
      mylist.append(checkVal)
      count += 1
    checkval += 1
  return mylist

# %%
def calculation(one, two):
  return one*two,one/two

myVal = calculation(9,2)
print(myVal[0])
print(myVal[1])
# Out:
# 18
# 4.5

# %%
myList = []
for i in range(1000):
  if (i%3 == 0) or (i%5 == 0):
    myList.append(i)

total = 0
for i in myList:
  total = total + i

  print(total)
# Out:
# 0
# 3
# 8
# 14
# 23
# 33
# 45
# 60
# 78
# 98
# 119
# 143
# 168
# 195
# 225
# 258
# 293
# 329
# 368
# 408
# 450
# 495
# 543
# 593
# 644
# 698
# 753
# 810
# 870
# 933
# 998
# 1064
# 1133
# 1203
# 1275
# 1350
# 1428
# 1508
# 1589
# 1673
# 1758
# 1845
# 1935
# 2028
# 2123
# 2219
# 2318
# 2418
# 2520
# 2625
# 2733
# 2843
# 2954
# 3068
# 3183
# 3300
# 3420
# 3543
# 3668
# 3794
# 3923
# 4053
# 4185
# 4320
# 4458
# 4598
# 4739
# 4883
# 5028
# 5175
# 5325
# 5478
# 5633
# 5789
# 5948
# 6108
# 6270
# 6435
# 6603
# 6773
# 6944
# 7118
# 7293
# 7470
# 7650
# 7833
# 8018
# 8204
# 8393
# 8583
# 8775
# 8970
# 9168
# 9368
# 9569
# 9773
# 9978
# 10185
# 10395
# 10608
# 10823
# 11039
# 11258
# 11478
# 11700
# 11925
# 12153
# 12383
# 12614
# 12848
# 13083
# 13320
# 13560
# 13803
# 14048
# 14294
# 14543
# 14793
# 15045
# 15300
# 15558
# 15818
# 16079
# 16343
# 16608
# 16875
# 17145
# 17418
# 17693
# 17969
# 18248
# 18528
# 18810
# 19095
# 19383
